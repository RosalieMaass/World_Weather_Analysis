# %%
#import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#add the latitudes and longitudes to alist
coordinates = list(lat_lngs)

# %%
#use the citipy module to determine city based on latitude and longitude
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 653

# %%
#import requests library
import requests

#import the api key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
 # Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["main"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | meybod
# Processing Record 2 of Set 1 | zigong
# Processing Record 3 of Set 1 | puerto madero
# Processing Record 4 of Set 1 | changji
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 1 | onega
# Processing Record 8 of Set 1 | sitka
# Processing Record 9 of Set 1 | east london
# Processing Record 10 of Set 1 | inveraray
# City not found. Skipping...
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 13 of Set 1 | chuy
# Processing Record 14 of Set 1 | lutz
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | sao filipe
# Processing Record 17 of Set 1 | khatanga
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | kyren
# Processing Record 20 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | torbay
# Processing Record 23 of Set 1 | margate
# Processing Record 24 of Set 1 | san juan
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | bilibino
# Processing Record 27 of Set 1 | ponta do sol
# Processing Record 28 of Set 1 | saint george
# Processing Record 29 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | nishihara
# Processing Record 32 of Set 1 | geraldton
# Processing Record 33 of Set 1 | santiago
# Processing Record 34 of Set 1 | victoria
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | te anau
# Processing Record 37 of Set 1 | jishou
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | zelenets
# Processing Record 40 of Set 1 | ixtapa
# Processing Record 41 of Set 1 | taraza
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | izhma
# Processing Record 45 of Set 1 | umm kaddadah
# Processing Record 46 of Set 1 | vilyuysk
# Processing Record 47 of Set 1 | alyangula
# Processing Record 48 of Set 1 | muli
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 1 of Set 2 | saint-augustin
# Processing Record 2 of Set 2 | turbat
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | port elizabeth
# Processing Record 5 of Set 2 | trebukhiv
# Processing Record 6 of Set 2 | livingston
# Processing Record 7 of Set 2 | wuxi
# Processing Record 8 of Set 2 | saskylakh
# Processing Record 9 of Set 2 | saint-philippe
# Processing Record 10 of Set 2 | sile
# Processing Record 11 of Set 2 | bathsheba
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | tarija
# Processing Record 14 of Set 2 | shchelyayur
# City not found. Skipping...
# Processing Record 15 of Set 2 | provideniya
# Processing Record 16 of Set 2 | semnan
# Processing Record 17 of Set 2 | verkhnyaya inta
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | auki
# Processing Record 20 of Set 2 | beloha
# Processing Record 21 of Set 2 | qingdao
# Processing Record 22 of Set 2 | talnakh
# Processing Record 23 of Set 2 | det udom
# Processing Record 24 of Set 2 | chokurdakh
# Processing Record 25 of Set 2 | whitefish
# Processing Record 26 of Set 2 | pangody
# Processing Record 27 of Set 2 | castro
# Processing Record 28 of Set 2 | anloga
# Processing Record 29 of Set 2 | pervomayskoye
# Processing Record 30 of Set 2 | ribeira grande
# Processing Record 31 of Set 2 | lunenburg
# Processing Record 32 of Set 2 | abu dhabi
# Processing Record 33 of Set 2 | kondinskoye
# Processing Record 34 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 2 | komsomolskiy
# Processing Record 36 of Set 2 | klaksvik
# Processing Record 37 of Set 2 | jamestown
# Processing Record 38 of Set 2 | hambantota
# Processing Record 39 of Set 2 | nouadhibou
# Processing Record 40 of Set 2 | umbuzeiro
# Processing Record 41 of Set 2 | canora
# Processing Record 42 of Set 2 | ayan
# Processing Record 43 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 2 | kodiak
# Processing Record 45 of Set 2 | toamasina
# Processing Record 46 of Set 2 | omboue
# Processing Record 47 of Set 2 | yar-sale
# Processing Record 48 of Set 2 | punta arenas
# Processing Record 49 of Set 2 | yarada
# Processing Record 50 of Set 2 | cidreira
# Processing Record 1 of Set 3 | hilo
# Processing Record 2 of Set 3 | kapaa
# Processing Record 3 of Set 3 | el alto
# Processing Record 4 of Set 3 | dikson
# Processing Record 5 of Set 3 | shubarkuduk
# Processing Record 6 of Set 3 | rikitea
# Processing Record 7 of Set 3 | nagorsk
# Processing Record 8 of Set 3 | puri
# Processing Record 9 of Set 3 | bethel
# Processing Record 10 of Set 3 | qaanaaq
# Processing Record 11 of Set 3 | vila
# Processing Record 12 of Set 3 | vallenar
# Processing Record 13 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 14 of Set 3 | butaritari
# Processing Record 15 of Set 3 | ayr
# Processing Record 16 of Set 3 | hasaki
# Processing Record 17 of Set 3 | aklavik
# Processing Record 18 of Set 3 | buenos aires
# Processing Record 19 of Set 3 | saint-denis
# Processing Record 20 of Set 3 | tshikapa
# Processing Record 21 of Set 3 | bandarbeyla
# Processing Record 22 of Set 3 | hithadhoo
# Processing Record 23 of Set 3 | necochea
# Processing Record 24 of Set 3 | novo aripuana
# Processing Record 25 of Set 3 | dhule
# Processing Record 26 of Set 3 | leningradskiy
# Processing Record 27 of Set 3 | airai
# Processing Record 28 of Set 3 | vestmannaeyjar
# Processing Record 29 of Set 3 | lebu
# Processing Record 30 of Set 3 | hervey bay
# Processing Record 31 of Set 3 | villanueva de la serena
# Processing Record 32 of Set 3 | solec kujawski
# Processing Record 33 of Set 3 | dubti
# Processing Record 34 of Set 3 | bredasdorp
# Processing Record 35 of Set 3 | grindavik
# Processing Record 36 of Set 3 | sola
# Processing Record 37 of Set 3 | kirkkonummi
# Processing Record 38 of Set 3 | kenora
# Processing Record 39 of Set 3 | palmer
# Processing Record 40 of Set 3 | yenagoa
# Processing Record 41 of Set 3 | salamiyah
# Processing Record 42 of Set 3 | alofi
# Processing Record 43 of Set 3 | tomelloso
# Processing Record 44 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 3 | karasjok
# Processing Record 46 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 47 of Set 3 | qovlar
# Processing Record 48 of Set 3 | dekar
# Processing Record 49 of Set 3 | bengkulu
# Processing Record 50 of Set 3 | husavik
# Processing Record 1 of Set 4 | svetlogorsk
# Processing Record 2 of Set 4 | anadyr
# Processing Record 3 of Set 4 | malibu
# Processing Record 4 of Set 4 | launceston
# Processing Record 5 of Set 4 | kawalu
# Processing Record 6 of Set 4 | lusaka
# Processing Record 7 of Set 4 | pauini
# Processing Record 8 of Set 4 | pachino
# Processing Record 9 of Set 4 | meulaboh
# Processing Record 10 of Set 4 | severo-kurilsk
# Processing Record 11 of Set 4 | clyde river
# Processing Record 12 of Set 4 | carnarvon
# Processing Record 13 of Set 4 | samarai
# Processing Record 14 of Set 4 | berlevag
# Processing Record 15 of Set 4 | hachinohe
# Processing Record 16 of Set 4 | kruisfontein
# Processing Record 17 of Set 4 | port alfred
# Processing Record 18 of Set 4 | trairi
# Processing Record 19 of Set 4 | kasongo-lunda
# Processing Record 20 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 4 | longyearbyen
# Processing Record 22 of Set 4 | sinop
# Processing Record 23 of Set 4 | constantine
# Processing Record 24 of Set 4 | nikolskoye
# Processing Record 25 of Set 4 | camacha
# Processing Record 26 of Set 4 | saldanha
# Processing Record 27 of Set 4 | pisco
# Processing Record 28 of Set 4 | nanortalik
# Processing Record 29 of Set 4 | karasburg
# Processing Record 30 of Set 4 | muleba
# Processing Record 31 of Set 4 | tuktoyaktuk
# Processing Record 32 of Set 4 | binzhou
# Processing Record 33 of Set 4 | kamaishi
# Processing Record 34 of Set 4 | cassilandia
# Processing Record 35 of Set 4 | issoudun
# Processing Record 36 of Set 4 | juxian
# City not found. Skipping...
# Processing Record 37 of Set 4 | lompoc
# Processing Record 38 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 39 of Set 4 | cabo san lucas
# Processing Record 40 of Set 4 | presidencia roque saenz pena
# Processing Record 41 of Set 4 | zhangjiakou
# Processing Record 42 of Set 4 | atuona
# Processing Record 43 of Set 4 | eyrarbakki
# Processing Record 44 of Set 4 | mar del plata
# Processing Record 45 of Set 4 | mosetse
# Processing Record 46 of Set 4 | bambous virieux
# Processing Record 47 of Set 4 | durban
# Processing Record 48 of Set 4 | batouri
# Processing Record 49 of Set 4 | pousat
# City not found. Skipping...
# Processing Record 50 of Set 4 | nyuksenitsa
# Processing Record 1 of Set 5 | sioux lookout
# Processing Record 2 of Set 5 | syracuse
# Processing Record 3 of Set 5 | athol
# Processing Record 4 of Set 5 | okha
# Processing Record 5 of Set 5 | noyabrsk
# Processing Record 6 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 7 of Set 5 | mildura
# Processing Record 8 of Set 5 | omsukchan
# Processing Record 9 of Set 5 | chapais
# Processing Record 10 of Set 5 | sungaipenuh
# Processing Record 11 of Set 5 | denpasar
# Processing Record 12 of Set 5 | mustasaari
# Processing Record 13 of Set 5 | porto novo
# Processing Record 14 of Set 5 | pangai
# Processing Record 15 of Set 5 | luau
# Processing Record 16 of Set 5 | olavarria
# Processing Record 17 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 5 | laguna
# Processing Record 19 of Set 5 | tugolesskiy bor
# Processing Record 20 of Set 5 | vilhena
# Processing Record 21 of Set 5 | cherskiy
# Processing Record 22 of Set 5 | yangjiang
# Processing Record 23 of Set 5 | upernavik
# Processing Record 24 of Set 5 | norman wells
# Processing Record 25 of Set 5 | fort wellington
# Processing Record 26 of Set 5 | fare
# Processing Record 27 of Set 5 | banda aceh
# Processing Record 28 of Set 5 | voh
# Processing Record 29 of Set 5 | utinga
# Processing Record 30 of Set 5 | santa maria
# Processing Record 31 of Set 5 | kamina
# Processing Record 32 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 5 | manicore
# Processing Record 34 of Set 5 | chumphon
# Processing Record 35 of Set 5 | bull savanna
# Processing Record 36 of Set 5 | gigmoto
# Processing Record 37 of Set 5 | byron bay
# Processing Record 38 of Set 5 | qasigiannguit
# Processing Record 39 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 40 of Set 5 | bakchar
# Processing Record 41 of Set 5 | port moresby
# Processing Record 42 of Set 5 | okhotsk
# Processing Record 43 of Set 5 | kutum
# Processing Record 44 of Set 5 | pevek
# Processing Record 45 of Set 5 | sangar
# Processing Record 46 of Set 5 | galashki
# Processing Record 47 of Set 5 | liku
# Processing Record 48 of Set 5 | vestmanna
# Processing Record 49 of Set 5 | mahebourg
# Processing Record 50 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 1 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 6 | kumano
# Processing Record 3 of Set 6 | karaton
# Processing Record 4 of Set 6 | vao
# Processing Record 5 of Set 6 | port keats
# Processing Record 6 of Set 6 | nizwa
# Processing Record 7 of Set 6 | padang
# Processing Record 8 of Set 6 | hvammstangi
# City not found. Skipping...
# Processing Record 9 of Set 6 | fort nelson
# Processing Record 10 of Set 6 | lufilufi
# Processing Record 11 of Set 6 | pasni
# Processing Record 12 of Set 6 | mugumu
# Processing Record 13 of Set 6 | kaeo
# Processing Record 14 of Set 6 | krasnoselkup
# Processing Record 15 of Set 6 | buala
# Processing Record 16 of Set 6 | salair
# Processing Record 17 of Set 6 | pokaran
# Processing Record 18 of Set 6 | henties bay
# Processing Record 19 of Set 6 | lavrentiya
# Processing Record 20 of Set 6 | cabedelo
# Processing Record 21 of Set 6 | peniche
# Processing Record 22 of Set 6 | eyemouth
# Processing Record 23 of Set 6 | patea
# Processing Record 24 of Set 6 | talcahuano
# Processing Record 25 of Set 6 | mizdah
# Processing Record 26 of Set 6 | pelaya
# Processing Record 27 of Set 6 | tartagal
# Processing Record 28 of Set 6 | bontang
# Processing Record 29 of Set 6 | puerto baquerizo moreno
# Processing Record 30 of Set 6 | klokkarvik
# City not found. Skipping...
# Processing Record 31 of Set 6 | paamiut
# Processing Record 32 of Set 6 | isangel
# Processing Record 33 of Set 6 | bacuit
# City not found. Skipping...
# Processing Record 34 of Set 6 | warstein
# Processing Record 35 of Set 6 | borovichi
# Processing Record 36 of Set 6 | monrovia
# Processing Record 37 of Set 6 | san patricio
# Processing Record 38 of Set 6 | hofn
# Processing Record 39 of Set 6 | santa rosa
# Processing Record 40 of Set 6 | lasa
# Processing Record 41 of Set 6 | mogadishu
# Processing Record 42 of Set 6 | abadzekhskaya
# Processing Record 43 of Set 6 | atasu
# Processing Record 44 of Set 6 | saint-joseph
# Processing Record 45 of Set 6 | mount isa
# Processing Record 46 of Set 6 | coffeyville
# Processing Record 47 of Set 6 | puerto ayacucho
# Processing Record 48 of Set 6 | mae ramat
# Processing Record 49 of Set 6 | kikwit
# Processing Record 50 of Set 6 | mizpe ramon
# City not found. Skipping...
# Processing Record 1 of Set 7 | gat
# Processing Record 2 of Set 7 | apam
# Processing Record 3 of Set 7 | freeport
# Processing Record 4 of Set 7 | concarneau
# Processing Record 5 of Set 7 | hailar
# Processing Record 6 of Set 7 | jaisalmer
# Processing Record 7 of Set 7 | borama
# City not found. Skipping...
# Processing Record 8 of Set 7 | la ronge
# Processing Record 9 of Set 7 | yulara
# Processing Record 10 of Set 7 | senador jose porfirio
# Processing Record 11 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 7 | tuatapere
# Processing Record 13 of Set 7 | mitsamiouli
# Processing Record 14 of Set 7 | keansburg
# Processing Record 15 of Set 7 | opuwo
# Processing Record 16 of Set 7 | manggar
# Processing Record 17 of Set 7 | benghazi
# Processing Record 18 of Set 7 | gabu
# Processing Record 19 of Set 7 | harper
# Processing Record 20 of Set 7 | lakhdenpokhya
# Processing Record 21 of Set 7 | oistins
# Processing Record 22 of Set 7 | san cristobal
# Processing Record 23 of Set 7 | panguna
# Processing Record 24 of Set 7 | soledade
# Processing Record 25 of Set 7 | floriano
# Processing Record 26 of Set 7 | georgetown
# Processing Record 27 of Set 7 | ocos
# Processing Record 28 of Set 7 | kalabo
# Processing Record 29 of Set 7 | mbekenyera
# Processing Record 30 of Set 7 | codrington
# Processing Record 31 of Set 7 | praia da vitoria
# Processing Record 32 of Set 7 | port lincoln
# Processing Record 33 of Set 7 | karlivka
# Processing Record 34 of Set 7 | penzance
# Processing Record 35 of Set 7 | kahului
# Processing Record 36 of Set 7 | guerrero negro
# Processing Record 37 of Set 7 | ketchikan
# Processing Record 38 of Set 7 | atar
# Processing Record 39 of Set 7 | iracoubo
# Processing Record 40 of Set 7 | riyadh
# Processing Record 41 of Set 7 | karratha
# Processing Record 42 of Set 7 | tasiilaq
# Processing Record 43 of Set 7 | gorom-gorom
# Processing Record 44 of Set 7 | arraial do cabo
# Processing Record 45 of Set 7 | dickinson
# Processing Record 46 of Set 7 | port hardy
# Processing Record 47 of Set 7 | adrar
# Processing Record 48 of Set 7 | formosa
# Processing Record 49 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 50 of Set 7 | doka
# Processing Record 1 of Set 8 | san rafael del sur
# Processing Record 2 of Set 8 | dumas
# Processing Record 3 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 8 | kulashi
# Processing Record 5 of Set 8 | halifax
# Processing Record 6 of Set 8 | havelock
# Processing Record 7 of Set 8 | narsaq
# Processing Record 8 of Set 8 | kaitangata
# Processing Record 9 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 8 | lorengau
# Processing Record 11 of Set 8 | woodward
# Processing Record 12 of Set 8 | sept-iles
# Processing Record 13 of Set 8 | esperance
# Processing Record 14 of Set 8 | esil
# Processing Record 15 of Set 8 | urumqi
# Processing Record 16 of Set 8 | landerneau
# Processing Record 17 of Set 8 | pa sang
# Processing Record 18 of Set 8 | darnah
# Processing Record 19 of Set 8 | pilar
# Processing Record 20 of Set 8 | san policarpo
# Processing Record 21 of Set 8 | atchison
# Processing Record 22 of Set 8 | arkul
# Processing Record 23 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 8 | batagay-alyta
# Processing Record 25 of Set 8 | ushtobe
# Processing Record 26 of Set 8 | viedma
# Processing Record 27 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 28 of Set 8 | arlit
# Processing Record 29 of Set 8 | murray bridge
# Processing Record 30 of Set 8 | san lorenzo
# Processing Record 31 of Set 8 | rio grande
# Processing Record 32 of Set 8 | sur
# Processing Record 33 of Set 8 | chitungwiza
# Processing Record 34 of Set 8 | klang
# Processing Record 35 of Set 8 | svobodnyy
# Processing Record 36 of Set 8 | mgandu
# Processing Record 37 of Set 8 | egvekinot
# Processing Record 38 of Set 8 | san quintin
# Processing Record 39 of Set 8 | lata
# Processing Record 40 of Set 8 | camocim
# Processing Record 41 of Set 8 | ovsyanka
# Processing Record 42 of Set 8 | svetlyy
# Processing Record 43 of Set 8 | tesistan
# Processing Record 44 of Set 8 | harrismith
# Processing Record 45 of Set 8 | araouane
# Processing Record 46 of Set 8 | tarko-sale
# Processing Record 47 of Set 8 | charters towers
# Processing Record 48 of Set 8 | acapulco
# Processing Record 49 of Set 8 | rovenki
# Processing Record 50 of Set 8 | reo
# Processing Record 1 of Set 9 | wencheng
# Processing Record 2 of Set 9 | jaca
# Processing Record 3 of Set 9 | hirara
# Processing Record 4 of Set 9 | maceio
# Processing Record 5 of Set 9 | brewster
# Processing Record 6 of Set 9 | sistranda
# Processing Record 7 of Set 9 | loiza
# Processing Record 8 of Set 9 | ylojarvi
# Processing Record 9 of Set 9 | takoradi
# Processing Record 10 of Set 9 | kjopsvik
# Processing Record 11 of Set 9 | amapa
# Processing Record 12 of Set 9 | greenville
# Processing Record 13 of Set 9 | dingle
# Processing Record 14 of Set 9 | cayenne
# Processing Record 15 of Set 9 | lugovoy
# Processing Record 16 of Set 9 | benemerito de las americas
# Processing Record 17 of Set 9 | ciudad bolivar
# Processing Record 18 of Set 9 | nuuk
# Processing Record 19 of Set 9 | kaseda
# Processing Record 20 of Set 9 | vardo
# Processing Record 21 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 9 | havre-saint-pierre
# Processing Record 23 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 24 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 9 | mackenzie
# Processing Record 26 of Set 9 | maua
# Processing Record 27 of Set 9 | marienburg
# Processing Record 28 of Set 9 | luderitz
# Processing Record 29 of Set 9 | havoysund
# Processing Record 30 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 9 | sobolevo
# Processing Record 32 of Set 9 | poronaysk
# Processing Record 33 of Set 9 | itaituba
# Processing Record 34 of Set 9 | phan thiet
# Processing Record 35 of Set 9 | qingan
# City not found. Skipping...
# Processing Record 36 of Set 9 | raga
# Processing Record 37 of Set 9 | olinda
# Processing Record 38 of Set 9 | shieli
# Processing Record 39 of Set 9 | cockburn town
# Processing Record 40 of Set 9 | seoul
# Processing Record 41 of Set 9 | kavieng
# Processing Record 42 of Set 9 | downers grove
# Processing Record 43 of Set 9 | maltahohe
# Processing Record 44 of Set 9 | mehamn
# Processing Record 45 of Set 9 | kuala terengganu
# Processing Record 46 of Set 9 | rafai
# Processing Record 47 of Set 9 | marzuq
# Processing Record 48 of Set 9 | bambanglipuro
# Processing Record 49 of Set 9 | tank
# Processing Record 50 of Set 9 | valdivia
# Processing Record 1 of Set 10 | luohe
# Processing Record 2 of Set 10 | ulaangom
# Processing Record 3 of Set 10 | floro
# Processing Record 4 of Set 10 | lloro
# Processing Record 5 of Set 10 | half moon bay
# Processing Record 6 of Set 10 | rancho palos verdes
# Processing Record 7 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 8 of Set 10 | chalus
# Processing Record 9 of Set 10 | teguldet
# Processing Record 10 of Set 10 | la cruz
# Processing Record 11 of Set 10 | rawson
# Processing Record 12 of Set 10 | pedasi
# Processing Record 13 of Set 10 | waingapu
# Processing Record 14 of Set 10 | baker city
# Processing Record 15 of Set 10 | port hueneme
# Processing Record 16 of Set 10 | asau
# Processing Record 17 of Set 10 | chicama
# Processing Record 18 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 20 of Set 10 | west wendover
# Processing Record 21 of Set 10 | strezhevoy
# Processing Record 22 of Set 10 | broome
# Processing Record 23 of Set 10 | surt
# Processing Record 24 of Set 10 | roermond
# Processing Record 25 of Set 10 | general roca
# Processing Record 26 of Set 10 | zhuhai
# Processing Record 27 of Set 10 | eldorado
# Processing Record 28 of Set 10 | balad
# Processing Record 29 of Set 10 | the valley
# Processing Record 30 of Set 10 | quang ngai
# Processing Record 31 of Set 10 | mitzic
# Processing Record 32 of Set 10 | tiksi
# Processing Record 33 of Set 10 | robertsport
# Processing Record 34 of Set 10 | maragogi
# Processing Record 35 of Set 10 | coahuayana
# Processing Record 36 of Set 10 | baykit
# Processing Record 37 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 10 | ulety
# Processing Record 39 of Set 10 | tual
# Processing Record 40 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 41 of Set 10 | mawlaik
# Processing Record 42 of Set 10 | sao joao da barra
# Processing Record 43 of Set 10 | vila franca do campo
# Processing Record 44 of Set 10 | beska
# Processing Record 45 of Set 10 | key biscayne
# Processing Record 46 of Set 10 | tuy hoa
# Processing Record 47 of Set 10 | bone
# Processing Record 48 of Set 10 | veracruz
# Processing Record 49 of Set 10 | chlorakas
# Processing Record 50 of Set 10 | thompson
# Processing Record 1 of Set 11 | mount gambier
# Processing Record 2 of Set 11 | kalmunai
# Processing Record 3 of Set 11 | bud
# Processing Record 4 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of Set 11 | zaysan
# Processing Record 6 of Set 11 | hami
# Processing Record 7 of Set 11 | kirakira
# Processing Record 8 of Set 11 | almeirim
# Processing Record 9 of Set 11 | darhan
# Processing Record 10 of Set 11 | carlisle
# Processing Record 11 of Set 11 | japura
# Processing Record 12 of Set 11 | shumskiy
# Processing Record 13 of Set 11 | hobyo
# Processing Record 14 of Set 11 | faanui
# Processing Record 15 of Set 11 | kieta
# Processing Record 16 of Set 11 | guiratinga
# Processing Record 17 of Set 11 | taldan
# Processing Record 18 of Set 11 | piacabucu
# Processing Record 19 of Set 11 | xining
# Processing Record 20 of Set 11 | karoi
# Processing Record 21 of Set 11 | iqaluit
# Processing Record 22 of Set 11 | mareeba
# Processing Record 23 of Set 11 | never
# Processing Record 24 of Set 11 | muisne
# Processing Record 25 of Set 11 | brandon
# Processing Record 26 of Set 11 | gamboma
# Processing Record 27 of Set 11 | hovd
# Processing Record 28 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 29 of Set 11 | tahta
# Processing Record 30 of Set 11 | goryachiy klyuch
# Processing Record 31 of Set 11 | constitucion
# Processing Record 32 of Set 11 | axim
# Processing Record 33 of Set 11 | altamira
# Processing Record 34 of Set 11 | sembe
# Processing Record 35 of Set 11 | pacific grove
# Processing Record 36 of Set 11 | taoudenni
# Processing Record 37 of Set 11 | merauke
# Processing Record 38 of Set 11 | beringovskiy
# Processing Record 39 of Set 11 | pincher creek
# Processing Record 40 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 41 of Set 11 | ancud
# Processing Record 42 of Set 11 | sarlat-la-caneda
# Processing Record 43 of Set 11 | ponta delgada
# Processing Record 44 of Set 11 | sinnamary
# Processing Record 45 of Set 11 | moussoro
# Processing Record 46 of Set 11 | bonfim
# Processing Record 47 of Set 11 | healdsburg
# Processing Record 48 of Set 11 | lagoa
# Processing Record 49 of Set 11 | koungou
# Processing Record 50 of Set 11 | bida
# Processing Record 1 of Set 12 | gouyave
# Processing Record 2 of Set 12 | muros
# Processing Record 3 of Set 12 | chara
# Processing Record 4 of Set 12 | dudinka
# Processing Record 5 of Set 12 | moskovskiy
# Processing Record 6 of Set 12 | nokaneng
# Processing Record 7 of Set 12 | ostersund
# Processing Record 8 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 12 | aykhal
# Processing Record 10 of Set 12 | manaus
# Processing Record 11 of Set 12 | korla
# Processing Record 12 of Set 12 | songea
# Processing Record 13 of Set 12 | akureyri
# Processing Record 14 of Set 12 | liwale
# Processing Record 15 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 16 of Set 12 | christchurch
# Processing Record 17 of Set 12 | la perla
# Processing Record 18 of Set 12 | salekhard
# Processing Record 19 of Set 12 | pangnirtung
# Processing Record 20 of Set 12 | port augusta
# Processing Record 21 of Set 12 | sorland
# Processing Record 22 of Set 12 | tura
# Processing Record 23 of Set 12 | labuhan
# Processing Record 24 of Set 12 | marrakesh
# Processing Record 25 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 26 of Set 12 | porbandar
# Processing Record 27 of Set 12 | awbari
# Processing Record 28 of Set 12 | saint anthony
# Processing Record 29 of Set 12 | polson
# Processing Record 30 of Set 12 | naryan-mar
# Processing Record 31 of Set 12 | bahir dar
# Processing Record 32 of Set 12 | okahandja
# Processing Record 33 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 12 | molchanovo
# Processing Record 36 of Set 12 | bara
# Processing Record 37 of Set 12 | nehe
# Processing Record 38 of Set 12 | ishigaki
# Processing Record 39 of Set 12 | bembereke
# Processing Record 40 of Set 12 | belomorsk
# Processing Record 41 of Set 12 | ramanuj ganj
# Processing Record 42 of Set 12 | punta alta
# Processing Record 43 of Set 12 | nueva guinea
# Processing Record 44 of Set 12 | kununurra
# Processing Record 45 of Set 12 | antsohihy
# Processing Record 46 of Set 12 | astoria
# Processing Record 47 of Set 12 | tazovskiy
# Processing Record 48 of Set 12 | baringo
# Processing Record 49 of Set 12 | kachikau
# City not found. Skipping...
# Processing Record 50 of Set 12 | hamilton
# Processing Record 1 of Set 13 | magadan
# Processing Record 2 of Set 13 | biloela
# Processing Record 3 of Set 13 | batemans bay
# Processing Record 4 of Set 13 | grand gaube
# Processing Record 5 of Set 13 | redlands
# Processing Record 6 of Set 13 | irtyshskiy
# Processing Record 7 of Set 13 | bardiyah
# Processing Record 8 of Set 13 | touros
# Processing Record 9 of Set 13 | fort morgan
# Processing Record 10 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 13 | miyako
# Processing Record 12 of Set 13 | rio gallegos
# Processing Record 13 of Set 13 | baruun-urt
# Processing Record 14 of Set 13 | hilton head island
# Processing Record 15 of Set 13 | oussouye
# Processing Record 16 of Set 13 | crotone
# Processing Record 17 of Set 13 | poum
# Processing Record 18 of Set 13 | avera
# Processing Record 19 of Set 13 | arona
# Processing Record 20 of Set 13 | college
# Processing Record 21 of Set 13 | kavaratti
# Processing Record 22 of Set 13 | fortuna
# Processing Record 23 of Set 13 | tres lagoas
# Processing Record 24 of Set 13 | antropovo
# Processing Record 25 of Set 13 | whitehorse
# Processing Record 26 of Set 13 | ksenyevka
# City not found. Skipping...
# Processing Record 27 of Set 13 | marawi
# Processing Record 28 of Set 13 | kjollefjord
# Processing Record 29 of Set 13 | yeppoon
# Processing Record 30 of Set 13 | moose factory
# Processing Record 31 of Set 13 | malaya vishera
# Processing Record 32 of Set 13 | moyale
# Processing Record 33 of Set 13 | borogontsy
# Processing Record 34 of Set 13 | nelson bay
# Processing Record 35 of Set 13 | merritt
# Processing Record 36 of Set 13 | port blair
# Processing Record 37 of Set 13 | okakarara
# Processing Record 38 of Set 13 | rioblanco
# Processing Record 39 of Set 13 | ossora
# Processing Record 40 of Set 13 | mani
# Processing Record 41 of Set 13 | kupang
# Processing Record 42 of Set 13 | ouallam
# Processing Record 43 of Set 13 | ormara
# Processing Record 44 of Set 13 | brigantine
# Processing Record 45 of Set 13 | tigzirt
# Processing Record 46 of Set 13 | bandundu
# Processing Record 47 of Set 13 | itajai
# Processing Record 48 of Set 13 | leshukonskoye
# Processing Record 49 of Set 13 | gualaca
# Processing Record 50 of Set 13 | bacungan
# Processing Record 1 of Set 14 | scarborough
# Processing Record 2 of Set 14 | coihaique
# Processing Record 3 of Set 14 | francisco sa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
#create the output file (csv)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
#export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
